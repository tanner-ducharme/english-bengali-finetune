# %%
import os
from huggingface_hub import notebook_login

os.environ["HF_TOKEN"] = "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"
notebook_login()

# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/MILA/WINTER2024/IFT6289-NLP/term_project/

import sys
# If your Python files are in the 'part2' directory or a subdirectory of it, add 'part2' to the path
sys.path.append('/content/drive/MyDrive/MILA/WINTER2024/IFT6289-NLP/term_project/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/MILA/WINTER2024/IFT6289-NLP/term_project

# %%
# !pip3 install -q -U datasets==2.17.0
# !pip3 install -q -U transformers==4.38.1
# !pip3 install -q -U sacrebleu
# !pip3 install -q -U peft
# !pip3 install -q -U bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 2.9 MB/s eta 0:00:00

# %%
model_name="tduch/ft-gemma-2b-lora-bn-en"

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, GemmaTokenizer, AutoModel
from peft import get_peft_config, get_peft_model, get_peft_model_state_dict, LoraConfig, TaskType


# quantization parameters
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# get model
model = AutoModelForCausalLM.from_pretrained("/ft-gemma-2b-lora-bn-en/adapter_model.safetensors")
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     397         # Load from URL or cache if already cached
# --> 398         resolved_file = hf_hub_download(
#     399             path_or_repo_id,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     109             if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 110                 validate_repo_id(arg_value)
#     111
#
# ...

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1f8a688cae5d> in <cell line: 1>()
# ----> 1 model
#
# NameError: name 'model' is not defined
